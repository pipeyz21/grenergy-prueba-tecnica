# %%
# Setup
import json
from pyspark.sql import functions as F

# Tabla de Configuración
df_config = spark.read.option("multiline", "true").json("Files/sources.json")

sources = [
    row.asDict(recursive=True)
    for row in df_config.filter(F.col("active") == True).collect()
]

notebookutils.notebook.exit(json.dumps(sources))
# Out:
# StatementMeta(, 73328358-3efb-4331-82b4-e29fa0fd0bca, 4, Finished, Available, Finished, False)
# ExitValue: [{"active": true, "auth": {"param_name": "securityToken", "secret_name": "entsoe-token", "type": "query_param"}, "country_code": "ES", "country_name": "Espa\u00f1a", "currency": "EUR", "dataset": "day_ahead_prices", "fetcher": "http_single", "format": "xml", "ingestion": {"lookback_days": 2, "start_date": "2026-08-01", "window_size_days": 1}, "parser": "entsoe_xml", "provider": "entsoe", "request": {"data_url": null, "index_selector": null, "index_url": null, "method": "GET", "query_params": {"$filter": null, "documentType": "A44", "in_Domain": "10YES-REE------0", "out_Domain": "10YES-REE------0", "periodEnd": "{window_end:%Y%m%d%H%M}", "periodStart": "{window_start:%Y%m%d%H%M}"}, "url": "https://web-api.tp.entsoe.eu/api"}, "source_id": "entsoe_es_dayahead", "source_timezone": "Europe/Madrid", "target_table": "bronze.prices_es", "unit": "EUR/MWh"}, {"active": true, "auth": {"param_name": "securityToken", "secret_name": "entsoe-token", "type": "query_param"}, "country_code": "RO", "country_name": "Rumania", "currency": "EUR", "dataset": "day_ahead_prices", "fetcher": "http_single", "format": "xml", "ingestion": {"lookback_days": 2, "start_date": "2026-08-01", "window_size_days": 1}, "parser": "entsoe_xml", "provider": "entsoe", "request": {"data_url": null, "index_selector": null, "index_url": null, "method": "GET", "query_params": {"$filter": null, "documentType": "A44", "in_Domain": "10YRO-TEL------P", "out_Domain": "10YRO-TEL------P", "periodEnd": "{window_end:%Y%m%d%H%M}", "periodStart": "{window_start:%Y%m%d%H%M}"}, "url": "https://web-api.tp.entsoe.eu/api"}, "source_id": "entsoe_ro_dayahead", "source_timezone": "Europe/Bucharest", "target_table": "bronze.prices_ro", "unit": "EUR/MWh"}, {"active": true, "auth": {"param_name": null, "secret_name": null, "type": "none"}, "country_code": "DE", "country_name": "Alemania", "currency": "EUR", "dataset": "day_ahead_prices", "fetcher": "http_index_then_file", "format": "json", "ingestion": {"lookback_days": 2, "start_date": "2026-08-01", "window_size_days": 1}, "parser": "smard_json", "provider": "smard", "request": {"data_url": "https://www.smard.de/app/chart_data/4169/DE/4169_DE_hour_{file_timestamp}.json", "index_selector": "timestamps", "index_url": "https://www.smard.de/app/chart_data/4169/DE/index_hour.json", "method": "GET", "query_params": null, "url": null}, "source_id": "smard_de_dayahead", "source_timezone": "Europe/Berlin", "target_table": "bronze.prices_de", "unit": "EUR/MWh"}, {"active": true, "auth": {"param_name": null, "secret_name": null, "type": "none"}, "country_code": "PL", "country_name": "Polonia", "currency": "PLN", "dataset": "day_ahead_prices", "fetcher": "http_single", "format": "json", "ingestion": {"lookback_days": 2, "start_date": "2026-08-01", "window_size_days": 1}, "parser": "pse_json", "provider": "pse", "request": {"data_url": null, "index_selector": null, "index_url": null, "method": "GET", "query_params": {"$filter": "business_date eq '{window_start:%Y-%m-%d}'", "documentType": null, "in_Domain": null, "out_Domain": null, "periodEnd": null, "periodStart": null}, "url": "https://api.raporty.pse.pl/api/rce-pln"}, "source_id": "pse_pl_rce", "source_timezone": "Europe/Warsaw", "target_table": "bronze.prices_pl", "unit": "PLN/MWh"}]
